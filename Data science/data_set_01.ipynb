# %%
import pandas as pd

# %%
data_frame=pd.read_csv("IMDB-Movie-Data.csv")
data_frame.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
find_repeat_dir=data_frame['Director'].value_counts()

# %%
find_repeat_dir.head()
# Out:
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
# Name: Director, dtype: int64

# %%
find_by_year=data_frame[data_frame['Year']==2012]
find_by_year.head()
# Out:
#      Rank                       Title                     Genre  \
# 1       2                  Prometheus  Adventure,Mystery,Sci-Fi
# 76     77                The Avengers             Action,Sci-Fi
# 124   125       The Dark Knight Rises           Action,Thriller
# 135   136  The Place Beyond the Pines      Crime,Drama,Thriller
# 144   145            Django Unchained             Drama,Western
#
#                                            Description           Director  \
# 1    Following clues to the origin of mankind, a te...       Ridley Scott
# 76   Earth's mightiest heroes must come together an...        Joss Whedon
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
# 135  A motorcycle stunt rider turns to robbing bank...   Derek Cianfrance
# 144  With the help of a German bounty hunter , a fr...  Quentin Tarantino
#
#                                                 Actors  Year  \
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# ...

# %%
find_by_runtime=data_frame[data_frame['Runtime (Minutes)']>=120]
find_by_runtime.head()
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 8     9       The Lost City of Z  Action,Adventure,Biography
#
#                                          Description         Director  \
# 0  A group of intergalactic criminals are forced ...       James Gunn
# 1  Following clues to the origin of mankind, a te...     Ridley Scott
# 4  A secret government agency recruits some of th...       David Ayer
# 6  A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 8  A true-life drama, centering on British explor...       James Gray
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# ...

# %%
find_by_rating=data_frame[data_frame['Rating']>6]
find_by_rating.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
find_by_meta_socre=data_frame[data_frame['Metascore']>50]
find_by_meta_socre.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 6     7               La La Land        Comedy,Drama,Music
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 6  A jazz pianist falls for an aspiring actress i...       Damien Chazelle
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
find_by_year=data_frame[(data_frame['Year']==2012) & (data_frame['Metascore']>=60) &(data_frame['Rating']>=6)]
find_by_year.head()
# Out:
#      Rank                       Title                     Genre  \
# 1       2                  Prometheus  Adventure,Mystery,Sci-Fi
# 76     77                The Avengers             Action,Sci-Fi
# 124   125       The Dark Knight Rises           Action,Thriller
# 135   136  The Place Beyond the Pines      Crime,Drama,Thriller
# 144   145            Django Unchained             Drama,Western
#
#                                            Description           Director  \
# 1    Following clues to the origin of mankind, a te...       Ridley Scott
# 76   Earth's mightiest heroes must come together an...        Joss Whedon
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
# 135  A motorcycle stunt rider turns to robbing bank...   Derek Cianfrance
# 144  With the help of a German bounty hunter , a fr...  Quentin Tarantino
#
#                                                 Actors  Year  \
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# ...

# %%
find_by_year=data_frame[(data_frame['Director']=='David Ayer')  & (data_frame['Rating']>6.0)]
find_by_year['Title']
# Out:
# 4      Suicide Squad
# 240             Fury
# 957     End of Watch
# Name: Title, dtype: object

# %%
find_by_heighest=max(data_frame['Rating'])
find_by_heighest
movie_with_high_rating=data_frame[(data_frame['Rating']==find_by_heighest)]
movie_with_high_rating
# Out:
#     Rank            Title               Genre  \
# 54    55  The Dark Knight  Action,Crime,Drama
#
#                                           Description           Director  \
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
#                                                Actors  Year  \
# 54  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
#
#     Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 54                152     9.0  1791916              533.32       82.0

# %%
find_by_heighest=max(data_frame['Metascore'])
find_by_heighest
movie_with_high_rating=data_frame[(data_frame['Metascore']==find_by_heighest)]
movie_with_high_rating
# Out:
#      Rank    Title  Genre                                        Description  \
# 656   657  Boyhood  Drama  The life of Mason, from early childhood to his...
#
#               Director                                             Actors  \
# 656  Richard Linklater  Ellar Coltrane, Patricia Arquette, Ethan Hawke...
#
#      Year  Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 656  2014                165     7.9  286722               25.36      100.0

# %%
find_by_heighest=max(data_frame['Revenue (Millions)'])
find_by_heighest
movie_with_high_rating=data_frame[(data_frame['Revenue (Millions)']==find_by_heighest)]
movie_with_high_rating
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 50                136     8.1  661608              936.63       81.0

# %%
find_passenger=data_frame.index[data_frame['Title']=='Passengers']
find_gold=data_frame.index[data_frame['Title']=='Gold']
print(find_passenger[0],find_gold[0])
data_frame.loc[find_passenger[0]:find_gold[0]]
# Out:
# 9 20
#     Rank                                    Title                       Genre  \
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# 12    13                                Rogue One     Action,Adventure,Sci-Fi
# 13    14                                    Moana  Animation,Adventure,Comedy
# 14    15                                 Colossal         Action,Comedy,Drama
# 15    16                  The Secret Life of Pets  Animation,Adventure,Comedy
# 16    17                            Hacksaw Ridge     Biography,Drama,History
# 17    18                             Jason Bourne             Action,Thriller
# 18    19                                     Lion             Biography,Drama
# 19    20                                  Arrival        Drama,Mystery,Sci-Fi
# ...

# %%
find_passenger=data_frame.index[data_frame['Title']=='Passengers']
find_gold=data_frame.index[data_frame['Title']=='Gold']
print(find_passenger[0],find_gold[0])
data_frame.iloc[find_passenger[0]:find_gold[0]]
# Out:
# 9 20
#     Rank                                    Title                       Genre  \
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# 12    13                                Rogue One     Action,Adventure,Sci-Fi
# 13    14                                    Moana  Animation,Adventure,Comedy
# 14    15                                 Colossal         Action,Comedy,Drama
# 15    16                  The Secret Life of Pets  Animation,Adventure,Comedy
# 16    17                            Hacksaw Ridge     Biography,Drama,History
# 17    18                             Jason Bourne             Action,Thriller
# 18    19                                     Lion             Biography,Drama
# 19    20                                  Arrival        Drama,Mystery,Sci-Fi
#
# ...
